# %%
from utils.logger_utils import *
from socials.questn_users_crawler import *
from socials.crew3_users_crawler import *
from databases.social_users_db import *
from cli.crawl_social_account import *

# %%
# "QuestNUserCrawler().get_quests()"

# %%
Crew3UserCrawler().get_top_communities()
# Out:
# [04-18-2023 21:28:25 +07] [INFO] [Crew3 User Crawler] - Loaded 100 communities after page [1]
# [04-18-2023 21:28:28 +07] [INFO] [Crew3 User Crawler] - Loaded 200 communities after page [2]
# [04-18-2023 21:28:31 +07] [INFO] [Crew3 User Crawler] - Loaded 300 communities after page [3]
# [04-18-2023 21:28:33 +07] [INFO] [Crew3 User Crawler] - Loaded 400 communities after page [4]
# [04-18-2023 21:28:36 +07] [INFO] [Crew3 User Crawler] - Loaded 500 communities after page [5]
# [04-18-2023 21:28:38 +07] [INFO] [Crew3 User Crawler] - Loaded 600 communities after page [6]
# [04-18-2023 21:28:41 +07] [INFO] [Crew3 User Crawler] - Loaded 700 communities after page [7]
# [04-18-2023 21:28:43 +07] [INFO] [Crew3 User Crawler] - Loaded 800 communities after page [8]
# [04-18-2023 21:28:45 +07] [INFO] [Crew3 User Crawler] - Loaded 900 communities after page [9]
# [04-18-2023 21:28:48 +07] [INFO] [Crew3 User Crawler] - Loaded 1000 communities after page [10]
# ...

# %%
import pandas as pd

# %%
ls
# Out:
# README.md         databases/        socials/          utils/
# cli/              main.py           test/
# crawl.ipynb       requirements.txt  test.ipynb

# %%
data = pd.read_json('test/Crew3/communities.json')

# %%
len(data.name.unique())
# Out:
# 56095

# %%
int('test_100')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/nguyenhuyhai/20222/lab_blockchain/crawl/crawlling/crawl.ipynb Cell 9' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/nguyenhuyhai/20222/lab_blockchain/crawl/crawlling/crawl.ipynb#ch0000008?line=0'>1</a> int('test_100')
#
# ValueError: invalid literal for int() with base 10: 'test_100'

# %%
string = 'data_100.json'
integer = int(string[5:8])
print(integer)  # Output: 100
# Out:
# 100
